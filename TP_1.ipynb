# %% [markdown]
# # Trabajo Práctico 1
# ## Clasificador de Recomendaciones Recreativas utilizando Procesamiento de Lenguaje Natural (NLP)
#
# ### Integrantes:
# * Longo, Gonzalo
# * Yañez, Mirian

# %% [markdown]
# Contexto: Una persona dentro de un mes, se tomará 15 días de vacaciones en la playa. Sin embargo, se estima que durante al menos cuatro de esos días habrá lluvias, lo que podría limitar las actividades al aire libre. Para esos días de mal clima, se propone una solución que facilite la recreación en función del estado de ánimo del día.
#
# Objetivo: Desarrollar un programa de Procesamiento de Lenguaje Natural que, según el estado de ánimo del usuario, recomiende entre ver una película, jugar un juego de mesa o leer un libro (o varias opciones para cada caso). Para ello, deberá construir un clasificador que categorice el estado de ánimo del usuario. Luego sugerir el conjunto de recomendaciones basada en una frase de preferencia ingresada por el usuario.
#
# Pasos para la construcción del proyecto:
#
# 1- Clasificación del Estado de Ánimo:
# Utilice los conocimientos aprendidos en la Unidad 3 para desarrollar un clasificador a partir de un prompt con el que determine el estado de ánimo del usuario, el cual deberá categorizarse por ejemplo: "Alegre", "Melancólico" o "Ni fu ni fa".
#
# 2- Ingreso de Preferencias:
# Una vez determinado el estado de ánimo, el usuario deberá ingresar una frase que describa la temática que le gustaría explorar. Por ejemplo: "una historia de amor en la selva".
#
# 3- Búsqueda de Opciones:
# El programa deberá comparar la frase ingresada por el usuario con diversas estructuras de texto provenientes de diferentes fuentes de datos utilizando los métodos aprendidos en clase.
#
# Disponga de los siguientes datasets:
# * bgg_database.csv: Base de datos de juegos de mesa.
# * IMDB-Movie-Data.csv: Base de datos de películas.
# * Libros del Proyecto Gutenberg: Realice web scraping para conformar un dataset con información sobre los 1000 libros más populares del Proyecto Gutenberg. El enlace a utilizar es el siguiente: https://www.gutenberg.org/browse/scores/top1000.php#books-last1.
#
# Recomendaciones:
# Con base en el estado de ánimo del usuario y la frase ingresada, el programa deberá ofrecer recomendaciones pertinentes entre películas, juegos de mesa o libros. Utilice las herramientas de NLP aprendidas en las tres primeras unidades para lograr resultados coherentes y personalizados.
#
# Requerimientos mínimos:
# * Utilice clasificadores para determinar el estado de ánimo (por ejemplo, métodos de clasificación supervisada).
# * Aplique técnicas de embeddings y comparación de similitud semántica para encontrar las mejores coincidencias en los datasets.
# * Utilice la potencia de reconocimiento de entidades nombradas, (NER, modelo Gliner) con el objetivo de obtener los mejores resultados buscados.
#
# Entrega:
#
# Se debe entregar un informe donde se documente cómo se implementa cada parte del programa, incluyendo explicaciones de cómo funcionan los algoritmos utilizados.
#
# Realice pruebas con diferentes ejemplos para mostrar la efectividad del clasificador y del sistema de recomendación.
#
# El código debe estar bien comentado y seguir buenas prácticas de programación. Debe utilizar entregar el o los colab utilizados en formato de notebook.
#
# Se debe entregar el dataset generado con el web scraping.
#
#
#
# Nota: Las fuentes de datos se encuentran en inglés, la aplicación debe comunicarse con el usuario en español.
#
# Opcional: Puede presentar una aplicación para el programa desarrollado, utilizando Google Colab con una interfaz sencilla basada en widgets como los proporcionados por la librería ip widgets.

# %% [markdown]
# ## Instalamos las dependencias

# %%
# !pip install gdown beautifulsoup4 lxml pysentimiento faiss-cpu sentence-transformers mtranslate ipywidgets
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (4.9.4)
# Collecting pysentimiento
#   Downloading pysentimiento-0.7.3-py3-none-any.whl.metadata (7.7 kB)
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Collecting sentence-transformers
#   Downloading sentence_transformers-3.2.1-py3-none-any.whl.metadata (10 kB)
# Collecting mtranslate
#   Downloading mtranslate-1.8.tar.gz (2.4 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.10/dist-packages (7.7.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.16.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: accelerate>=0.27.2 in /usr/local/lib/python3.10/dist-packages (from pysentimiento) (0.34.2)
# Collecting datasets>=2.10.1 (from pysentimiento)
#   Downloading datasets-3.0.2-py3-none-any.whl.metadata (20 kB)
# Collecting emoji>=1.6.1 (from pysentimiento)
#   Downloading emoji-2.14.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: spacy>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from pysentimiento) (3.7.5)
# Requirement already satisfied: torch!=2.0.1,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pysentimiento) (2.5.0+cu121)
# Requirement already satisfied: transformers>=4.13.0 in /usr/local/lib/python3.10/dist-packages (from pysentimiento) (4.44.2)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.10/dist-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from faiss-cpu) (24.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.5.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.24.7)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (10.4.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (3.0.13)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.27.2->pysentimiento) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.27.2->pysentimiento) (6.0.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.27.2->pysentimiento) (0.4.5)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.10.1->pysentimiento) (16.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets>=2.10.1->pysentimiento)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets>=2.10.1->pysentimiento) (2.2.2)
# Collecting xxhash (from datasets>=2.10.1->pysentimiento)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets>=2.10.1->pysentimiento)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets>=2.10.1->pysentimiento) (2024.6.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.10.1->pysentimiento) (3.10.10)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (4.12.2)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets) (6.3.3)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (75.1.0)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (3.0.48)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (4.9.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.5.0->pysentimiento) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.5.0->pysentimiento) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.5.0->pysentimiento) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.5.0->pysentimiento) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.5.0->pysentimiento) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.5.0->pysentimiento) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.5.0->pysentimiento) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.5.0->pysentimiento) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.5.0->pysentimiento) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.5.0->pysentimiento) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.5.0->pysentimiento) (0.12.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.5.0->pysentimiento) (2.9.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.5.0->pysentimiento) (3.1.4)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.5.0->pysentimiento) (3.4.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch!=2.0.1,>=2.0.0->pysentimiento) (3.4.2)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch!=2.0.1,>=2.0.0->pysentimiento) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch!=2.0.1,>=2.0.0->pysentimiento) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.13.0->pysentimiento) (2024.9.11)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.13.0->pysentimiento) (0.19.1)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets) (6.5.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2024.8.30)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.10.1->pysentimiento) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.10.1->pysentimiento) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.10.1->pysentimiento) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.10.1->pysentimiento) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.10.1->pysentimiento) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.10.1->pysentimiento) (1.16.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.10.1->pysentimiento) (4.0.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy>=3.5.0->pysentimiento) (1.2.0)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (24.0.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.7.2)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.6.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.21.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.10/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.2.13)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.5.0->pysentimiento) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.5.0->pysentimiento) (2.23.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy>=3.5.0->pysentimiento) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy>=3.5.0->pysentimiento) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy>=3.5.0->pysentimiento) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy>=3.5.0->pysentimiento) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy>=3.5.0->pysentimiento) (13.9.3)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy>=3.5.0->pysentimiento) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy>=3.5.0->pysentimiento) (7.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy>=3.5.0->pysentimiento) (3.0.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.10.1->pysentimiento) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.10.1->pysentimiento) (2024.2)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.3.6)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy>=3.5.0->pysentimiento) (1.2.1)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.2.4)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.3.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.5.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.3.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.23.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.1->jupyter-client->ipykernel>=4.5.1->ipywidgets) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=3.5.0->pysentimiento) (3.0.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy>=3.5.0->pysentimiento) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets>=2.10.1->pysentimiento) (0.2.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (21.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=3.5.0->pysentimiento) (0.1.2)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.10/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.24.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.17.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.22)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.8.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.2.2)
# Downloading pysentimiento-0.7.3-py3-none-any.whl (39 kB)
# Downloading faiss_cpu-1.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (27.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.5/27.5 MB 75.2 MB/s eta 0:00:00
# Downloading sentence_transformers-3.2.1-py3-none-any.whl (255 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.8/255.8 kB 17.4 MB/s eta 0:00:00
# Downloading datasets-3.0.2-py3-none-any.whl (472 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.7/472.7 kB 29.3 MB/s eta 0:00:00
# Downloading emoji-2.14.0-py3-none-any.whl (586 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 586.9/586.9 kB 41.4 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.1 MB/s eta 0:00:00
# Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 69.6 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.0 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 17.8 MB/s eta 0:00:00
# Building wheels for collected packages: mtranslate
#   Building wheel for mtranslate (setup.py) ... done
#   Created wheel for mtranslate: filename=mtranslate-1.8-py3-none-any.whl size=3673 sha256=f437a3931f0bfa2d5bbc1b01dddefe888c87db13a00f2b18692ada364be776e4
#   Stored in directory: /root/.cache/pip/wheels/c2/04/15/d7654c2c4a9a52e09922967593f3278fed66059be65ca671ea
# Successfully built mtranslate
# Installing collected packages: mtranslate, xxhash, jedi, faiss-cpu, emoji, dill, multiprocess, sentence-transformers, datasets, pysentimiento
# Successfully installed datasets-3.0.2 dill-0.3.8 emoji-2.14.0 faiss-cpu-1.9.0 jedi-0.19.1 mtranslate-1.8 multiprocess-0.70.16 pysentimiento-0.7.3 sentence-transformers-3.2.1 xxhash-3.5.0

# %% [markdown]
# # Descargamos el Dataset

# %%
import gdown
url = 'https://drive.google.com/drive/folders/1xjkuCdlnRkWMOrdbZ-i49K_oWMP8TP8Y'
gdown.download_folder(url, output='data', quiet=False, use_cookies=False)
# Out:
# Retrieving folder contents
# Processing file 1yIWOgUV5WyskQvmq48QvF2Lzr0LxpAdq bgg_database.csv
# Processing file 1YCu3xhZq4C5dYyekiluMabwyWBqQyd2c IMDB-Movie-Data.csv
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=1yIWOgUV5WyskQvmq48QvF2Lzr0LxpAdq
# To: /content/data/bgg_database.csv
# 100%|██████████| 1.83M/1.83M [00:00<00:00, 204MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1YCu3xhZq4C5dYyekiluMabwyWBqQyd2c
# To: /content/data/IMDB-Movie-Data.csv
# 100%|██████████| 309k/309k [00:00<00:00, 120MB/s]
# Download completed
# ['data/bgg_database.csv', 'data/IMDB-Movie-Data.csv']

# %% [markdown]
# # Scrapper De Libros

# %%
import requests
from bs4 import BeautifulSoup
import csv
import ssl
import concurrent.futures
import time

ssl._create_default_https_context = ssl._create_unverified_context

class ScrapperBooks:
    def __init__(self, url):
        self.url = url

    def get_books(self):
        response = requests.get(self.url)
        soup = BeautifulSoup(response.content, 'html.parser')
        div = soup.find_all('div', class_='page_content')[0]
        ol = div.find('ol')
        return ['https://www.gutenberg.org' + li.find('a')['href'] for li in ol.find_all('li')]

    def get_book_details(self, book_url):
        print(book_url)
        response = requests.get(book_url)
        soup = BeautifulSoup(response.content, 'html.parser')
        table = soup.find('table', class_='bibrec')
        details = {
            tr.th.get_text(strip=True): tr.td.get_text(strip=True)
            for tr in table.find_all('tr')
            if tr.th and tr.td and tr.th.get_text(strip=True) in {'Author', 'Title', 'Summary'}
        }
        details['Link'] = book_url
        return details

    def save_to_csv(self, data, filename='data/books.csv'):
        with open(filename, mode='w', newline='', encoding='utf-8') as file:
            writer = csv.DictWriter(file, fieldnames=['Title', 'Author', 'Summary', 'Link'])
            writer.writeheader()
            writer.writerows(data)

    def run(self):
        start_time = time.time()
        books = self.get_books()
        with concurrent.futures.ThreadPoolExecutor() as executor:
            books_details = list(executor.map(self.get_book_details, books))
        self.save_to_csv(books_details)
        print(f"{len(books_details)} libros guardados en 'books.csv'.")
        elapsed_time = time.time() - start_time
        print(f"Tiempo total: {elapsed_time:.2f} segundos")

# %%
scraper = ScrapperBooks("https://www.gutenberg.org/browse/scores/top1000.php#books-last1")
scraper.run()
# Out:
# https://www.gutenberg.org/ebooks/84
# https://www.gutenberg.org/ebooks/1342
# https://www.gutenberg.org/ebooks/2701
# https://www.gutenberg.org/ebooks/1513
# https://www.gutenberg.org/ebooks/25344
# https://www.gutenberg.org/ebooks/100
# https://www.gutenberg.org/ebooks/145
# https://www.gutenberg.org/ebooks/2641
# https://www.gutenberg.org/ebooks/11
# https://www.gutenberg.org/ebooks/37106
# https://www.gutenberg.org/ebooks/41
# https://www.gutenberg.org/ebooks/67979
# https://www.gutenberg.org/ebooks/16389
# https://www.gutenberg.org/ebooks/6761
# https://www.gutenberg.org/ebooks/394
# https://www.gutenberg.org/ebooks/2160
# https://www.gutenberg.org/ebooks/6593
# https://www.gutenberg.org/ebooks/4085
# https://www.gutenberg.org/ebooks/5197https://www.gutenberg.org/ebooks/1259
#
# https://www.gutenberg.org/ebooks/174https://www.gutenberg.org/ebooks/2542
#
# https://www.gutenberg.org/ebooks/345
# https://www.gutenberg.org/ebooks/76
# https://www.gutenberg.org/ebooks/64317
# https://www.gutenberg.org/ebooks/25558
# https://www.gutenberg.org/ebooks/43https://www.gutenberg.org/ebooks/1080
# https://www.gutenberg.org/ebooks/5200
# https://www.gutenberg.org/ebooks/844https://www.gutenberg.org/ebooks/1952
#
# https://www.gutenberg.org/ebooks/2554
#
# https://www.gutenberg.org/ebooks/3207
# https://www.gutenberg.org/ebooks/98
# https://www.gutenberg.org/ebooks/74635
# https://www.gutenberg.org/ebooks/74633
# https://www.gutenberg.org/ebooks/46
# https://www.gutenberg.org/ebooks/2591
# https://www.gutenberg.org/ebooks/1998
# https://www.gutenberg.org/ebooks/1260
# https://www.gutenberg.org/ebooks/205
# https://www.gutenberg.org/ebooks/1232
# https://www.gutenberg.org/ebooks/28054
# https://www.gutenberg.org/ebooks/1661
# https://www.gutenberg.org/ebooks/6130
# https://www.gutenberg.org/ebooks/1400
# https://www.gutenberg.org/ebooks/74
# https://www.gutenberg.org/ebooks/408
# https://www.gutenberg.org/ebooks/74636
# https://www.gutenberg.org/ebooks/7370
# https://www.gutenberg.org/ebooks/49010
# https://www.gutenberg.org/ebooks/4300
# https://www.gutenberg.org/ebooks/74632https://www.gutenberg.org/ebooks/16328
#
# https://www.gutenberg.org/ebooks/2000
# https://www.gutenberg.org/ebooks/2600
# https://www.gutenberg.org/ebooks/4363
# https://www.gutenberg.org/ebooks/3296
# https://www.gutenberg.org/ebooks/23
# https://www.gutenberg.org/ebooks/768
# https://www.gutenberg.org/ebooks/1184https://www.gutenberg.org/ebooks/1727
#
# https://www.gutenberg.org/ebooks/5740
# https://www.gutenberg.org/ebooks/2148
# https://www.gutenberg.org/ebooks/219
# https://www.gutenberg.org/ebooks/2650
# https://www.gutenberg.org/ebooks/41445
# https://www.gutenberg.org/ebooks/30254
# https://www.gutenberg.org/ebooks/36034
# https://www.gutenberg.org/ebooks/8800
# https://www.gutenberg.org/ebooks/1497
# https://www.gutenberg.org/ebooks/42324
# https://www.gutenberg.org/ebooks/45
# https://www.gutenberg.org/ebooks/50150
# https://www.gutenberg.org/ebooks/15399https://www.gutenberg.org/ebooks/33283
#
# https://www.gutenberg.org/ebooks/244
# https://www.gutenberg.org/ebooks/730
# https://www.gutenberg.org/ebooks/779
# https://www.gutenberg.org/ebooks/996
# https://www.gutenberg.org/ebooks/8492
# https://www.gutenberg.org/ebooks/10007
# https://www.gutenberg.org/ebooks/16119
# https://www.gutenberg.org/ebooks/514
# https://www.gutenberg.org/ebooks/1251
# https://www.gutenberg.org/ebooks/27827
# https://www.gutenberg.org/ebooks/2814
# https://www.gutenberg.org/ebooks/17489
# https://www.gutenberg.org/ebooks/74638
# https://www.gutenberg.org/ebooks/31284
# https://www.gutenberg.org/ebooks/74630
# https://www.gutenberg.org/ebooks/55
# https://www.gutenberg.org/ebooks/2852
# https://www.gutenberg.org/ebooks/67098
# https://www.gutenberg.org/ebooks/27761
# https://www.gutenberg.org/ebooks/15272
# https://www.gutenberg.org/ebooks/20203
# https://www.gutenberg.org/ebooks/19942
# https://www.gutenberg.org/ebooks/5827
# https://www.gutenberg.org/ebooks/34901https://www.gutenberg.org/ebooks/36
#
# https://www.gutenberg.org/ebooks/2680
# https://www.gutenberg.org/ebooks/74631
# https://www.gutenberg.org/ebooks/12
# https://www.gutenberg.org/ebooks/132
# https://www.gutenberg.org/ebooks/120
# https://www.gutenberg.org/ebooks/16
# https://www.gutenberg.org/ebooks/10
# https://www.gutenberg.org/ebooks/600
# https://www.gutenberg.org/ebooks/8438
# https://www.gutenberg.org/ebooks/37683
# https://www.gutenberg.org/ebooks/12116
# https://www.gutenberg.org/ebooks/14328
# https://www.gutenberg.org/ebooks/158
# https://www.gutenberg.org/ebooks/135
# https://www.gutenberg.org/ebooks/10623
# https://www.gutenberg.org/ebooks/4217
# https://www.gutenberg.org/ebooks/4280
# https://www.gutenberg.org/ebooks/31552https://www.gutenberg.org/ebooks/58585
#
# https://www.gutenberg.org/ebooks/20738
# https://www.gutenberg.org/ebooks/10615https://www.gutenberg.org/ebooks/69087
#
# https://www.gutenberg.org/ebooks/21765
# https://www.gutenberg.org/ebooks/22381
# https://www.gutenberg.org/ebooks/1228
# https://www.gutenberg.org/ebooks/2848
# https://www.gutenberg.org/ebooks/398
# https://www.gutenberg.org/ebooks/27673
# https://www.gutenberg.org/ebooks/2413
# https://www.gutenberg.org/ebooks/161
# https://www.gutenberg.org/ebooks/70891
# https://www.gutenberg.org/ebooks/37134
# https://www.gutenberg.org/ebooks/7142
# https://www.gutenberg.org/ebooks/18269
# https://www.gutenberg.org/ebooks/11030
# https://www.gutenberg.org/ebooks/209https://www.gutenberg.org/ebooks/147
#
# https://www.gutenberg.org/ebooks/26https://www.gutenberg.org/ebooks/829
#
# https://www.gutenberg.org/ebooks/1399
# https://www.gutenberg.org/ebooks/3300
# https://www.gutenberg.org/ebooks/1170
# https://www.gutenberg.org/ebooks/41562
# https://www.gutenberg.org/ebooks/6087
# https://www.gutenberg.org/ebooks/24869
# https://www.gutenberg.org/ebooks/29728
# https://www.gutenberg.org/ebooks/160
# https://www.gutenberg.org/ebooks/2527
# https://www.gutenberg.org/ebooks/1532https://www.gutenberg.org/ebooks/164
#
# https://www.gutenberg.org/ebooks/203
# https://www.gutenberg.org/ebooks/52319
# https://www.gutenberg.org/ebooks/2147
# https://www.gutenberg.org/ebooks/43453
# https://www.gutenberg.org/ebooks/51356
# https://www.gutenberg.org/ebooks/766https://www.gutenberg.org/ebooks/521
#
# https://www.gutenberg.org/ebooks/3825
# https://www.gutenberg.org/ebooks/5131
# https://www.gutenberg.org/ebooks/20228
# https://www.gutenberg.org/ebooks/3600
# https://www.gutenberg.org/ebooks/786
# https://www.gutenberg.org/ebooks/35
# https://www.gutenberg.org/ebooks/7700
# https://www.gutenberg.org/ebooks/45502
# https://www.gutenberg.org/ebooks/1636
# https://www.gutenberg.org/ebooks/19033
# https://www.gutenberg.org/ebooks/245
# https://www.gutenberg.org/ebooks/3800
# https://www.gutenberg.org/ebooks/35899
# https://www.gutenberg.org/ebooks/1934
# https://www.gutenberg.org/ebooks/72679
# https://www.gutenberg.org/ebooks/1250
# https://www.gutenberg.org/ebooks/815
# https://www.gutenberg.org/ebooks/851https://www.gutenberg.org/ebooks/42
# https://www.gutenberg.org/ebooks/2707
#
# https://www.gutenberg.org/ebooks/14591
# https://www.gutenberg.org/ebooks/105
# https://www.gutenberg.org/ebooks/1837
# https://www.gutenberg.org/ebooks/1754
# https://www.gutenberg.org/ebooks/5230
# https://www.gutenberg.org/ebooks/14568
# https://www.gutenberg.org/ebooks/25305
# https://www.gutenberg.org/ebooks/6737https://www.gutenberg.org/ebooks/4517
#
# https://www.gutenberg.org/ebooks/4093
# https://www.gutenberg.org/ebooks/39962
# https://www.gutenberg.org/ebooks/23042
# https://www.gutenberg.org/ebooks/39287
# https://www.gutenberg.org/ebooks/28890
# https://www.gutenberg.org/ebooks/16527
# https://www.gutenberg.org/ebooks/39960
# https://www.gutenberg.org/ebooks/17396
# https://www.gutenberg.org/ebooks/696
# https://www.gutenberg.org/ebooks/11339
# https://www.gutenberg.org/ebooks/58221
# https://www.gutenberg.org/ebooks/24022
# https://www.gutenberg.org/ebooks/21700
# https://www.gutenberg.org/ebooks/74629
# https://www.gutenberg.org/ebooks/45631
# https://www.gutenberg.org/ebooks/121
# https://www.gutenberg.org/ebooks/1057
# https://www.gutenberg.org/ebooks/236
# https://www.gutenberg.org/ebooks/10676
# https://www.gutenberg.org/ebooks/49965
# https://www.gutenberg.org/ebooks/921
# https://www.gutenberg.org/ebooks/1063https://www.gutenberg.org/ebooks/215
# https://www.gutenberg.org/ebooks/74626
#
# https://www.gutenberg.org/ebooks/74634
# https://www.gutenberg.org/ebooks/2097
# https://www.gutenberg.org/ebooks/9662
# https://www.gutenberg.org/ebooks/30201
# https://www.gutenberg.org/ebooks/51233
# https://www.gutenberg.org/ebooks/1533
# https://www.gutenberg.org/ebooks/59
# https://www.gutenberg.org/ebooks/140
# https://www.gutenberg.org/ebooks/12342
# https://www.gutenberg.org/ebooks/1524
# https://www.gutenberg.org/ebooks/3176
# https://www.gutenberg.org/ebooks/2500
# https://www.gutenberg.org/ebooks/512
# https://www.gutenberg.org/ebooks/22120
# https://www.gutenberg.org/ebooks/34206
# https://www.gutenberg.org/ebooks/3090
# https://www.gutenberg.org/ebooks/13951
# https://www.gutenberg.org/ebooks/1600
# https://www.gutenberg.org/ebooks/67092
# https://www.gutenberg.org/ebooks/13415
# https://www.gutenberg.org/ebooks/1946
# https://www.gutenberg.org/ebooks/2130
# https://www.gutenberg.org/ebooks/50742
# https://www.gutenberg.org/ebooks/45315
# https://www.gutenberg.org/ebooks/61
# https://www.gutenberg.org/ebooks/52263
# https://www.gutenberg.org/ebooks/1023
# https://www.gutenberg.org/ebooks/21279
# https://www.gutenberg.org/ebooks/15474
# https://www.gutenberg.org/ebooks/2199
# https://www.gutenberg.org/ebooks/55201
# https://www.gutenberg.org/ebooks/23817
# https://www.gutenberg.org/ebooks/29433
# https://www.gutenberg.org/ebooks/23700
# https://www.gutenberg.org/ebooks/2638
# https://www.gutenberg.org/ebooks/12122https://www.gutenberg.org/ebooks/10625
#
# https://www.gutenberg.org/ebooks/18600
# https://www.gutenberg.org/ebooks/17989
# https://www.gutenberg.org/ebooks/71865
# https://www.gutenberg.org/ebooks/10897
# https://www.gutenberg.org/ebooks/14838
# https://www.gutenberg.org/ebooks/863
# https://www.gutenberg.org/ebooks/25717
# https://www.gutenberg.org/ebooks/70954
# https://www.gutenberg.org/ebooks/50922
# https://www.gutenberg.org/ebooks/308https://www.gutenberg.org/ebooks/141
#
# https://www.gutenberg.org/ebooks/25282
# https://www.gutenberg.org/ebooks/972https://www.gutenberg.org/ebooks/27083
# https://www.gutenberg.org/ebooks/31516
#
# https://www.gutenberg.org/ebooks/18857
# https://www.gutenberg.org/ebooks/994
# https://www.gutenberg.org/ebooks/8581
# https://www.gutenberg.org/ebooks/7849https://www.gutenberg.org/ebooks/24571
#
# https://www.gutenberg.org/ebooks/2781
# https://www.gutenberg.org/ebooks/902
# https://www.gutenberg.org/ebooks/14977
# https://www.gutenberg.org/ebooks/12242
# https://www.gutenberg.org/ebooks/23218
# https://www.gutenberg.org/ebooks/40986
# https://www.gutenberg.org/ebooks/26000
# https://www.gutenberg.org/ebooks/46976
# https://www.gutenberg.org/ebooks/9800
# https://www.gutenberg.org/ebooks/389
# https://www.gutenberg.org/ebooks/1064
# https://www.gutenberg.org/ebooks/3201https://www.gutenberg.org/ebooks/57426
#
# https://www.gutenberg.org/ebooks/1974
# https://www.gutenberg.org/ebooks/932
# https://www.gutenberg.org/ebooks/1514https://www.gutenberg.org/ebooks/36098
#
# https://www.gutenberg.org/ebooks/910
# https://www.gutenberg.org/ebooks/73
# https://www.gutenberg.org/ebooks/6400
# https://www.gutenberg.org/ebooks/80https://www.gutenberg.org/ebooks/6133
#
# https://www.gutenberg.org/ebooks/103
# https://www.gutenberg.org/ebooks/86
# https://www.gutenberg.org/ebooks/52206
# https://www.gutenberg.org/ebooks/1526
# https://www.gutenberg.org/ebooks/32https://www.gutenberg.org/ebooks/175
# https://www.gutenberg.org/ebooks/2232
# https://www.gutenberg.org/ebooks/8117
#
# https://www.gutenberg.org/ebooks/7131
# https://www.gutenberg.org/ebooks/19322
# https://www.gutenberg.org/ebooks/45304
# https://www.gutenberg.org/ebooks/6099
# https://www.gutenberg.org/ebooks/25141
# https://www.gutenberg.org/ebooks/541
# https://www.gutenberg.org/ebooks/35451
# https://www.gutenberg.org/ebooks/580
# https://www.gutenberg.org/ebooks/7256
# https://www.gutenberg.org/ebooks/383
# https://www.gutenberg.org/ebooks/2610
# https://www.gutenberg.org/ebooks/35123
# https://www.gutenberg.org/ebooks/8578
# https://www.gutenberg.org/ebooks/3289
# https://www.gutenberg.org/ebooks/71062
# https://www.gutenberg.org/ebooks/14155
# https://www.gutenberg.org/ebooks/7144
# https://www.gutenberg.org/ebooks/67138
# https://www.gutenberg.org/ebooks/4078
# https://www.gutenberg.org/ebooks/11231
# https://www.gutenberg.org/ebooks/15353
# https://www.gutenberg.org/ebooks/1001
# https://www.gutenberg.org/ebooks/3213
# https://www.gutenberg.org/ebooks/38269https://www.gutenberg.org/ebooks/8121
#
# https://www.gutenberg.org/ebooks/74628
# https://www.gutenberg.org/ebooks/2529
# https://www.gutenberg.org/ebooks/59112
# https://www.gutenberg.org/ebooks/110
# https://www.gutenberg.org/ebooks/599
# https://www.gutenberg.org/ebooks/10636
# https://www.gutenberg.org/ebooks/9700
# https://www.gutenberg.org/ebooks/805
# https://www.gutenberg.org/ebooks/40745
# https://www.gutenberg.org/ebooks/74624
# https://www.gutenberg.org/ebooks/47629
# https://www.gutenberg.org/ebooks/1515https://www.gutenberg.org/ebooks/71
#
# https://www.gutenberg.org/ebooks/159
# https://www.gutenberg.org/ebooks/61262
# https://www.gutenberg.org/ebooks/82https://www.gutenberg.org/ebooks/36459
#
# https://www.gutenberg.org/ebooks/38326
# https://www.gutenberg.org/ebooks/1404
# https://www.gutenberg.org/ebooks/375
# https://www.gutenberg.org/ebooks/2850
# https://www.gutenberg.org/ebooks/27200
# https://www.gutenberg.org/ebooks/45109
# https://www.gutenberg.org/ebooks/5225
# https://www.gutenberg.org/ebooks/14975
# https://www.gutenberg.org/ebooks/16643
# https://www.gutenberg.org/ebooks/38427https://www.gutenberg.org/ebooks/57303
#
# https://www.gutenberg.org/ebooks/41537
# https://www.gutenberg.org/ebooks/7178
# https://www.gutenberg.org/ebooks/16966
# https://www.gutenberg.org/ebooks/20239
# https://www.gutenberg.org/ebooks/6124
# https://www.gutenberg.org/ebooks/52958
# https://www.gutenberg.org/ebooks/1079
# https://www.gutenberg.org/ebooks/42884
# https://www.gutenberg.org/ebooks/289
# https://www.gutenberg.org/ebooks/114
# https://www.gutenberg.org/ebooks/27805
# https://www.gutenberg.org/ebooks/1322
# https://www.gutenberg.org/ebooks/1756
# https://www.gutenberg.org/ebooks/10681
# https://www.gutenberg.org/ebooks/22444
# https://www.gutenberg.org/ebooks/2388
# https://www.gutenberg.org/ebooks/35018
# https://www.gutenberg.org/ebooks/885
# https://www.gutenberg.org/ebooks/3333
# https://www.gutenberg.org/ebooks/19994
# https://www.gutenberg.org/ebooks/1091
# https://www.gutenberg.org/ebooks/22367
# https://www.gutenberg.org/ebooks/500
# https://www.gutenberg.org/ebooks/32854
# https://www.gutenberg.org/ebooks/5921
# https://www.gutenberg.org/ebooks/146
# https://www.gutenberg.org/ebooks/38488
# https://www.gutenberg.org/ebooks/51
# https://www.gutenberg.org/ebooks/68283
# https://www.gutenberg.org/ebooks/3188
# https://www.gutenberg.org/ebooks/1658
# https://www.gutenberg.org/ebooks/19337
# https://www.gutenberg.org/ebooks/2383
# https://www.gutenberg.org/ebooks/10732
# https://www.gutenberg.org/ebooks/32474
# https://www.gutenberg.org/ebooks/26659
# https://www.gutenberg.org/ebooks/1672
# https://www.gutenberg.org/ebooks/1254
# https://www.gutenberg.org/ebooks/38769
# https://www.gutenberg.org/ebooks/1906
# https://www.gutenberg.org/ebooks/7205
# https://www.gutenberg.org/ebooks/4705
# https://www.gutenberg.org/ebooks/3328
# https://www.gutenberg.org/ebooks/1531
# https://www.gutenberg.org/ebooks/52205
# https://www.gutenberg.org/ebooks/61221
# https://www.gutenberg.org/ebooks/13437
# https://www.gutenberg.org/ebooks/59563
# https://www.gutenberg.org/ebooks/45634
# https://www.gutenberg.org/ebooks/1429
# https://www.gutenberg.org/ebooks/816
# https://www.gutenberg.org/ebooks/2587
# https://www.gutenberg.org/ebooks/40074
# https://www.gutenberg.org/ebooks/56463
# https://www.gutenberg.org/ebooks/1
# https://www.gutenberg.org/ebooks/834
# https://www.gutenberg.org/ebooks/271
# https://www.gutenberg.org/ebooks/74614
# https://www.gutenberg.org/ebooks/42166
# https://www.gutenberg.org/ebooks/36238
# https://www.gutenberg.org/ebooks/3420
# https://www.gutenberg.org/ebooks/4099
# https://www.gutenberg.org/ebooks/10150
# https://www.gutenberg.org/ebooks/21
# https://www.gutenberg.org/ebooks/228
# https://www.gutenberg.org/ebooks/4276
# https://www.gutenberg.org/ebooks/28497
# https://www.gutenberg.org/ebooks/20
# https://www.gutenberg.org/ebooks/33812
# https://www.gutenberg.org/ebooks/9842
# https://www.gutenberg.org/ebooks/1257
# https://www.gutenberg.org/ebooks/3011
# https://www.gutenberg.org/ebooks/14988
# https://www.gutenberg.org/ebooks/1719
# https://www.gutenberg.org/ebooks/66048
# https://www.gutenberg.org/ebooks/8102
# https://www.gutenberg.org/ebooks/4367
# https://www.gutenberg.org/ebooks/7524
# https://www.gutenberg.org/ebooks/61963
# https://www.gutenberg.org/ebooks/36805
# https://www.gutenberg.org/ebooks/60479
# https://www.gutenberg.org/ebooks/9105
# https://www.gutenberg.org/ebooks/9622https://www.gutenberg.org/ebooks/19725
#
# https://www.gutenberg.org/ebooks/35977
# https://www.gutenberg.org/ebooks/2376
# https://www.gutenberg.org/ebooks/39293
# https://www.gutenberg.org/ebooks/798
# https://www.gutenberg.org/ebooks/17957
# https://www.gutenberg.org/ebooks/37423
# https://www.gutenberg.org/ebooks/2981
# https://www.gutenberg.org/ebooks/1874
# https://www.gutenberg.org/ebooks/5720
# https://www.gutenberg.org/ebooks/74621https://www.gutenberg.org/ebooks/3618
#
# https://www.gutenberg.org/ebooks/52190
# https://www.gutenberg.org/ebooks/17157
# https://www.gutenberg.org/ebooks/41128
# https://www.gutenberg.org/ebooks/10800
# https://www.gutenberg.org/ebooks/14859
# https://www.gutenberg.org/ebooks/23962
# https://www.gutenberg.org/ebooks/4081
# https://www.gutenberg.org/ebooks/8710
# https://www.gutenberg.org/ebooks/421
# https://www.gutenberg.org/ebooks/41360
# https://www.gutenberg.org/ebooks/2559
# https://www.gutenberg.org/ebooks/1081
# https://www.gutenberg.org/ebooks/46333
# https://www.gutenberg.org/ebooks/26300
# https://www.gutenberg.org/ebooks/15210
# https://www.gutenberg.org/ebooks/24029
# https://www.gutenberg.org/ebooks/2446
# https://www.gutenberg.org/ebooks/60976
# https://www.gutenberg.org/ebooks/64908
# https://www.gutenberg.org/ebooks/5116
# https://www.gutenberg.org/ebooks/830
# https://www.gutenberg.org/ebooks/55317
# https://www.gutenberg.org/ebooks/51060
# https://www.gutenberg.org/ebooks/22400
# https://www.gutenberg.org/ebooks/36708
# https://www.gutenberg.org/ebooks/29214
# https://www.gutenberg.org/ebooks/1522
# https://www.gutenberg.org/ebooks/66923
# https://www.gutenberg.org/ebooks/67799
# https://www.gutenberg.org/ebooks/3186
# https://www.gutenberg.org/ebooks/1519
# https://www.gutenberg.org/ebooks/10947
# https://www.gutenberg.org/ebooks/55822
# https://www.gutenberg.org/ebooks/33870
# https://www.gutenberg.org/ebooks/74625
# https://www.gutenberg.org/ebooks/38145
# https://www.gutenberg.org/ebooks/28794
# https://www.gutenberg.org/ebooks/15725
# https://www.gutenberg.org/ebooks/70516
# https://www.gutenberg.org/ebooks/52006https://www.gutenberg.org/ebooks/790
#
# https://www.gutenberg.org/ebooks/50307
# https://www.gutenberg.org/ebooks/2048
# https://www.gutenberg.org/ebooks/2490
# https://www.gutenberg.org/ebooks/1597
# https://www.gutenberg.org/ebooks/33
# https://www.gutenberg.org/ebooks/47
# https://www.gutenberg.org/ebooks/35690
# https://www.gutenberg.org/ebooks/73312
# https://www.gutenberg.org/ebooks/43007
# https://www.gutenberg.org/ebooks/19681
# https://www.gutenberg.org/ebooks/36092
# https://www.gutenberg.org/ebooks/11870
# https://www.gutenberg.org/ebooks/70https://www.gutenberg.org/ebooks/1292https://www.gutenberg.org/ebooks/22456
#
#
# https://www.gutenberg.org/ebooks/14209
# https://www.gutenberg.org/ebooks/20321https://www.gutenberg.org/ebooks/108
#
# https://www.gutenberg.org/ebooks/1656
# https://www.gutenberg.org/ebooks/10148
# https://www.gutenberg.org/ebooks/1430
# https://www.gutenberg.org/ebooks/78
# https://www.gutenberg.org/ebooks/583
# https://www.gutenberg.org/ebooks/28522
# https://www.gutenberg.org/ebooks/10609
# https://www.gutenberg.org/ebooks/24113
# https://www.gutenberg.org/ebooks/130
# https://www.gutenberg.org/ebooks/1252
# https://www.gutenberg.org/ebooks/852
# https://www.gutenberg.org/ebooks/57333
# https://www.gutenberg.org/ebooks/550https://www.gutenberg.org/ebooks/409https://www.gutenberg.org/ebooks/58866
#
# https://www.gutenberg.org/ebooks/1695
# https://www.gutenberg.org/ebooks/31591
# https://www.gutenberg.org/ebooks/3177
#
# https://www.gutenberg.org/ebooks/2946
# https://www.gutenberg.org/ebooks/62383
# https://www.gutenberg.org/ebooks/503
# https://www.gutenberg.org/ebooks/17116
# https://www.gutenberg.org/ebooks/67961
# https://www.gutenberg.org/ebooks/3567
# https://www.gutenberg.org/ebooks/9551
# https://www.gutenberg.org/ebooks/74548
# https://www.gutenberg.org/ebooks/5669
# https://www.gutenberg.org/ebooks/48247
# https://www.gutenberg.org/ebooks/17851
# https://www.gutenberg.org/ebooks/21183
# https://www.gutenberg.org/ebooks/18947
# https://www.gutenberg.org/ebooks/16269
# https://www.gutenberg.org/ebooks/4507
# https://www.gutenberg.org/ebooks/65661
# https://www.gutenberg.org/ebooks/5427https://www.gutenberg.org/ebooks/50133
#
# https://www.gutenberg.org/ebooks/26184
# https://www.gutenberg.org/ebooks/6157https://www.gutenberg.org/ebooks/119
# https://www.gutenberg.org/ebooks/3913
# https://www.gutenberg.org/ebooks/64977
#
# https://www.gutenberg.org/ebooks/69566https://www.gutenberg.org/ebooks/376
#
# https://www.gutenberg.org/ebooks/28809
# https://www.gutenberg.org/ebooks/49513
# https://www.gutenberg.org/ebooks/131
# https://www.gutenberg.org/ebooks/16564
# https://www.gutenberg.org/ebooks/17405
# https://www.gutenberg.org/ebooks/11224
# https://www.gutenberg.org/ebooks/31543
# https://www.gutenberg.org/ebooks/48438
# https://www.gutenberg.org/ebooks/785
# https://www.gutenberg.org/ebooks/876
# https://www.gutenberg.org/ebooks/1887https://www.gutenberg.org/ebooks/6762
# https://www.gutenberg.org/ebooks/11945
#
# https://www.gutenberg.org/ebooks/7986
# https://www.gutenberg.org/ebooks/60093
# https://www.gutenberg.org/ebooks/1097
# https://www.gutenberg.org/ebooks/5402
# https://www.gutenberg.org/ebooks/39452
# https://www.gutenberg.org/ebooks/2499
# https://www.gutenberg.org/ebooks/25525
# https://www.gutenberg.org/ebooks/610
# https://www.gutenberg.org/ebooks/13707
# https://www.gutenberg.org/ebooks/14354
# https://www.gutenberg.org/ebooks/2992
# https://www.gutenberg.org/ebooks/64974
# https://www.gutenberg.org/ebooks/11438
# https://www.gutenberg.org/ebooks/883
# https://www.gutenberg.org/ebooks/1549
# https://www.gutenberg.org/ebooks/40409
# https://www.gutenberg.org/ebooks/8775
# https://www.gutenberg.org/ebooks/14522
# https://www.gutenberg.org/ebooks/2040
# https://www.gutenberg.org/ebooks/4039
# https://www.gutenberg.org/ebooks/26285
# https://www.gutenberg.org/ebooks/1200
# https://www.gutenberg.org/ebooks/60464
# https://www.gutenberg.org/ebooks/1572
# https://www.gutenberg.org/ebooks/6081
# https://www.gutenberg.org/ebooks/8300
# https://www.gutenberg.org/ebooks/348
# https://www.gutenberg.org/ebooks/11748
# https://www.gutenberg.org/ebooks/57628
# https://www.gutenberg.org/ebooks/57037
# https://www.gutenberg.org/ebooks/45839
# https://www.gutenberg.org/ebooks/18442
# https://www.gutenberg.org/ebooks/257
# https://www.gutenberg.org/ebooks/17192
# https://www.gutenberg.org/ebooks/11136
# https://www.gutenberg.org/ebooks/227
# https://www.gutenberg.org/ebooks/6688
# https://www.gutenberg.org/ebooks/13846
# https://www.gutenberg.org/ebooks/4028
# https://www.gutenberg.org/ebooks/1564
# https://www.gutenberg.org/ebooks/3178
# https://www.gutenberg.org/ebooks/26487
# https://www.gutenberg.org/ebooks/940
# https://www.gutenberg.org/ebooks/15396
# https://www.gutenberg.org/ebooks/10741
# https://www.gutenberg.org/ebooks/74618
# https://www.gutenberg.org/ebooks/15532
# https://www.gutenberg.org/ebooks/26654
# https://www.gutenberg.org/ebooks/657
# https://www.gutenberg.org/ebooks/1056https://www.gutenberg.org/ebooks/1450
# https://www.gutenberg.org/ebooks/45305
#
# https://www.gutenberg.org/ebooks/148
# https://www.gutenberg.org/ebooks/544
# https://www.gutenberg.org/ebooks/74637
# https://www.gutenberg.org/ebooks/47287
# https://www.gutenberg.org/ebooks/29145
# https://www.gutenberg.org/ebooks/73549
# https://www.gutenberg.org/ebooks/284
# https://www.gutenberg.org/ebooks/25929https://www.gutenberg.org/ebooks/66057
#
# https://www.gutenberg.org/ebooks/52914
# https://www.gutenberg.org/ebooks/1150
# https://www.gutenberg.org/ebooks/5682
# https://www.gutenberg.org/ebooks/43936
# https://www.gutenberg.org/ebooks/16317
# https://www.gutenberg.org/ebooks/2151
# https://www.gutenberg.org/ebooks/14314
# https://www.gutenberg.org/ebooks/1929
# https://www.gutenberg.org/ebooks/55264
# https://www.gutenberg.org/ebooks/39647
# https://www.gutenberg.org/ebooks/5683
# https://www.gutenberg.org/ebooks/28513
# https://www.gutenberg.org/ebooks/42053https://www.gutenberg.org/ebooks/5658
#
# https://www.gutenberg.org/ebooks/28233
# https://www.gutenberg.org/ebooks/1653
# https://www.gutenberg.org/ebooks/14005
# https://www.gutenberg.org/ebooks/34906
# https://www.gutenberg.org/ebooks/77
# https://www.gutenberg.org/ebooks/2131
# https://www.gutenberg.org/ebooks/2009
# https://www.gutenberg.org/ebooks/65993
# https://www.gutenberg.org/ebooks/40580
# https://www.gutenberg.org/ebooks/708
# https://www.gutenberg.org/ebooks/21076
# https://www.gutenberg.org/ebooks/29765
# https://www.gutenberg.org/ebooks/2226
# https://www.gutenberg.org/ebooks/45524
# https://www.gutenberg.org/ebooks/17150
# https://www.gutenberg.org/ebooks/14741
# https://www.gutenberg.org/ebooks/2833
# https://www.gutenberg.org/ebooks/73144
# https://www.gutenberg.org/ebooks/23938
# https://www.gutenberg.org/ebooks/60
# https://www.gutenberg.org/ebooks/35439
# https://www.gutenberg.org/ebooks/5333
# https://www.gutenberg.org/ebooks/39742
# https://www.gutenberg.org/ebooks/49836
# https://www.gutenberg.org/ebooks/25063
# https://www.gutenberg.org/ebooks/222
# https://www.gutenberg.org/ebooks/3268
# https://www.gutenberg.org/ebooks/447
# https://www.gutenberg.org/ebooks/12513
# https://www.gutenberg.org/ebooks/21000
# https://www.gutenberg.org/ebooks/29558
# https://www.gutenberg.org/ebooks/2488
# https://www.gutenberg.org/ebooks/963
# https://www.gutenberg.org/ebooks/1279
# https://www.gutenberg.org/ebooks/20480
# https://www.gutenberg.org/ebooks/63380
# https://www.gutenberg.org/ebooks/74576
# https://www.gutenberg.org/ebooks/55687
# https://www.gutenberg.org/ebooks/54027
# https://www.gutenberg.org/ebooks/43010
# https://www.gutenberg.org/ebooks/3174
# https://www.gutenberg.org/ebooks/9603
# https://www.gutenberg.org/ebooks/4320
# https://www.gutenberg.org/ebooks/28
# https://www.gutenberg.org/ebooks/233https://www.gutenberg.org/ebooks/74612
# https://www.gutenberg.org/ebooks/8525
#
# https://www.gutenberg.org/ebooks/107
# https://www.gutenberg.org/ebooks/13507
# https://www.gutenberg.org/ebooks/969
# https://www.gutenberg.org/ebooks/10031
# https://www.gutenberg.org/ebooks/20748
# https://www.gutenberg.org/ebooks/47001
# https://www.gutenberg.org/ebooks/42796
# https://www.gutenberg.org/ebooks/10607
# https://www.gutenberg.org/ebooks/31
# https://www.gutenberg.org/ebooks/27035
# https://www.gutenberg.org/ebooks/12814
# https://www.gutenberg.org/ebooks/38015
# https://www.gutenberg.org/ebooks/25716
# https://www.gutenberg.org/ebooks/13726
# https://www.gutenberg.org/ebooks/12753
# https://www.gutenberg.org/ebooks/28488
# https://www.gutenberg.org/ebooks/59844
# https://www.gutenberg.org/ebooks/16464https://www.gutenberg.org/ebooks/42704
#
# https://www.gutenberg.org/ebooks/71031
# https://www.gutenberg.org/ebooks/5186
# https://www.gutenberg.org/ebooks/23045https://www.gutenberg.org/ebooks/39955
#
# https://www.gutenberg.org/ebooks/54700
# https://www.gutenberg.org/ebooks/598
# https://www.gutenberg.org/ebooks/128
# https://www.gutenberg.org/ebooks/65903
# https://www.gutenberg.org/ebooks/20776
# https://www.gutenberg.org/ebooks/30107
# https://www.gutenberg.org/ebooks/14471
# https://www.gutenberg.org/ebooks/47677
# https://www.gutenberg.org/ebooks/416
# https://www.gutenberg.org/ebooks/155
# https://www.gutenberg.org/ebooks/10814
# https://www.gutenberg.org/ebooks/14417
# https://www.gutenberg.org/ebooks/2811
# https://www.gutenberg.org/ebooks/22452
# https://www.gutenberg.org/ebooks/44747
# https://www.gutenberg.org/ebooks/901
# https://www.gutenberg.org/ebooks/3008
# https://www.gutenberg.org/ebooks/52881
# https://www.gutenberg.org/ebooks/28900
# https://www.gutenberg.org/ebooks/7439
# https://www.gutenberg.org/ebooks/61851
# https://www.gutenberg.org/ebooks/9182
# https://www.gutenberg.org/ebooks/242
# https://www.gutenberg.org/ebooks/41568
# https://www.gutenberg.org/ebooks/30073
# https://www.gutenberg.org/ebooks/29515
# https://www.gutenberg.org/ebooks/1021
# https://www.gutenberg.org/ebooks/4010
# https://www.gutenberg.org/ebooks/18772
# https://www.gutenberg.org/ebooks/20916
# https://www.gutenberg.org/ebooks/1280
# https://www.gutenberg.org/ebooks/102
# https://www.gutenberg.org/ebooks/3080
# https://www.gutenberg.org/ebooks/52821
# https://www.gutenberg.org/ebooks/42671
# https://www.gutenberg.org/ebooks/40686
# https://www.gutenberg.org/ebooks/847
# https://www.gutenberg.org/ebooks/1642
# https://www.gutenberg.org/ebooks/12096https://www.gutenberg.org/ebooks/1093
# https://www.gutenberg.org/ebooks/62940
# https://www.gutenberg.org/ebooks/11756
#
# https://www.gutenberg.org/ebooks/8954https://www.gutenberg.org/ebooks/62
#
# https://www.gutenberg.org/ebooks/16452
# https://www.gutenberg.org/ebooks/9070
# https://www.gutenberg.org/ebooks/3623
# https://www.gutenberg.org/ebooks/5428
# https://www.gutenberg.org/ebooks/1152
# https://www.gutenberg.org/ebooks/2397
# https://www.gutenberg.org/ebooks/5316
# https://www.gutenberg.org/ebooks/113
# https://www.gutenberg.org/ebooks/73011
# https://www.gutenberg.org/ebooks/5739
# https://www.gutenberg.org/ebooks/5201
# https://www.gutenberg.org/ebooks/1591
# https://www.gutenberg.org/ebooks/986
# https://www.gutenberg.org/ebooks/1750
# https://www.gutenberg.org/ebooks/24518
# https://www.gutenberg.org/ebooks/61130
# https://www.gutenberg.org/ebooks/15859
# https://www.gutenberg.org/ebooks/558
# https://www.gutenberg.org/ebooks/325
# https://www.gutenberg.org/ebooks/64264
# https://www.gutenberg.org/ebooks/4361
# https://www.gutenberg.org/ebooks/4791
# https://www.gutenberg.org/ebooks/6626
# https://www.gutenberg.org/ebooks/3189
# https://www.gutenberg.org/ebooks/202
# https://www.gutenberg.org/ebooks/23639
# https://www.gutenberg.org/ebooks/2197
# https://www.gutenberg.org/ebooks/31509
# https://www.gutenberg.org/ebooks/22823
# https://www.gutenberg.org/ebooks/32032
# https://www.gutenberg.org/ebooks/201
# https://www.gutenberg.org/ebooks/42290
# https://www.gutenberg.org/ebooks/19481
# https://www.gutenberg.org/ebooks/43851
# https://www.gutenberg.org/ebooks/22633
# https://www.gutenberg.org/ebooks/28554
# https://www.gutenberg.org/ebooks/23172
# https://www.gutenberg.org/ebooks/1643
# https://www.gutenberg.org/ebooks/2911
# https://www.gutenberg.org/ebooks/14872
# https://www.gutenberg.org/ebooks/17149
# https://www.gutenberg.org/ebooks/25564
# https://www.gutenberg.org/ebooks/4018
# https://www.gutenberg.org/ebooks/8299
# https://www.gutenberg.org/ebooks/70956
# https://www.gutenberg.org/ebooks/55752
# https://www.gutenberg.org/ebooks/27122
# https://www.gutenberg.org/ebooks/6867
# https://www.gutenberg.org/ebooks/61168
# https://www.gutenberg.org/ebooks/6523
# https://www.gutenberg.org/ebooks/2229
# https://www.gutenberg.org/ebooks/1726https://www.gutenberg.org/ebooks/27326
#
# https://www.gutenberg.org/ebooks/1210
# https://www.gutenberg.org/ebooks/8486
# https://www.gutenberg.org/ebooks/43629
# https://www.gutenberg.org/ebooks/22448
# https://www.gutenberg.org/ebooks/50572
# https://www.gutenberg.org/ebooks/5983
# https://www.gutenberg.org/ebooks/13701
# https://www.gutenberg.org/ebooks/47151
# https://www.gutenberg.org/ebooks/31193
# https://www.gutenberg.org/ebooks/45858
# https://www.gutenberg.org/ebooks/70819
# https://www.gutenberg.org/ebooks/6852
# https://www.gutenberg.org/ebooks/14033
# https://www.gutenberg.org/ebooks/2428
# https://www.gutenberg.org/ebooks/5001
# https://www.gutenberg.org/ebooks/38219https://www.gutenberg.org/ebooks/10715
#
# https://www.gutenberg.org/ebooks/55283
# https://www.gutenberg.org/ebooks/14264
# https://www.gutenberg.org/ebooks/35249
# https://www.gutenberg.org/ebooks/1074
# https://www.gutenberg.org/ebooks/21020
# https://www.gutenberg.org/ebooks/3160
# https://www.gutenberg.org/ebooks/54873
# https://www.gutenberg.org/ebooks/25664
# https://www.gutenberg.org/ebooks/217https://www.gutenberg.org/ebooks/3
#
# https://www.gutenberg.org/ebooks/48612
# https://www.gutenberg.org/ebooks/23997
# https://www.gutenberg.org/ebooks/13529
# https://www.gutenberg.org/ebooks/23722
# https://www.gutenberg.org/ebooks/72824https://www.gutenberg.org/ebooks/55387
#
# https://www.gutenberg.org/ebooks/71059https://www.gutenberg.org/ebooks/2017
#
# https://www.gutenberg.org/ebooks/46740
# https://www.gutenberg.org/ebooks/16713
# https://www.gutenberg.org/ebooks/74602https://www.gutenberg.org/ebooks/1321
#
# https://www.gutenberg.org/ebooks/1041
# https://www.gutenberg.org/ebooks/70114
# https://www.gutenberg.org/ebooks/24950
# https://www.gutenberg.org/ebooks/4583
# https://www.gutenberg.org/ebooks/13549
# https://www.gutenberg.org/ebooks/29220
# https://www.gutenberg.org/ebooks/15250
# https://www.gutenberg.org/ebooks/41617
# https://www.gutenberg.org/ebooks/38503
# https://www.gutenberg.org/ebooks/48465
# https://www.gutenberg.org/ebooks/7452
# https://www.gutenberg.org/ebooks/23850
# https://www.gutenberg.org/ebooks/39270
# https://www.gutenberg.org/ebooks/37841
# https://www.gutenberg.org/ebooks/2085
# https://www.gutenberg.org/ebooks/56852
# https://www.gutenberg.org/ebooks/2350
# https://www.gutenberg.org/ebooks/2449
# https://www.gutenberg.org/ebooks/2166
# https://www.gutenberg.org/ebooks/2895
# https://www.gutenberg.org/ebooks/204
# https://www.gutenberg.org/ebooks/29827
# https://www.gutenberg.org/ebooks/139
# https://www.gutenberg.org/ebooks/1155
# https://www.gutenberg.org/ebooks/57342
# https://www.gutenberg.org/ebooks/12949https://www.gutenberg.org/ebooks/26558
#
# https://www.gutenberg.org/ebooks/14407
# https://www.gutenberg.org/ebooks/151
# https://www.gutenberg.org/ebooks/50603
# https://www.gutenberg.org/ebooks/51143
# https://www.gutenberg.org/ebooks/1268
# https://www.gutenberg.org/ebooks/32449
# https://www.gutenberg.org/ebooks/54824
# https://www.gutenberg.org/ebooks/5000
# https://www.gutenberg.org/ebooks/21522
# https://www.gutenberg.org/ebooks/68811
# https://www.gutenberg.org/ebooks/28521
# https://www.gutenberg.org/ebooks/2434
# https://www.gutenberg.org/ebooks/7321
# https://www.gutenberg.org/ebooks/974
# https://www.gutenberg.org/ebooks/50280
# https://www.gutenberg.org/ebooks/710
# https://www.gutenberg.org/ebooks/18
# https://www.gutenberg.org/ebooks/9830
# https://www.gutenberg.org/ebooks/35587
# https://www.gutenberg.org/ebooks/14244
# https://www.gutenberg.org/ebooks/15781
# https://www.gutenberg.org/ebooks/479
# https://www.gutenberg.org/ebooks/74222
# https://www.gutenberg.org/ebooks/39184
# https://www.gutenberg.org/ebooks/4352
# https://www.gutenberg.org/ebooks/153
# https://www.gutenberg.org/ebooks/14837
# https://www.gutenberg.org/ebooks/17161
# https://www.gutenberg.org/ebooks/33887
# https://www.gutenberg.org/ebooks/15114
# https://www.gutenberg.org/ebooks/35843
# https://www.gutenberg.org/ebooks/1635
# https://www.gutenberg.org/ebooks/5
# https://www.gutenberg.org/ebooks/10554
# https://www.gutenberg.org/ebooks/1237
# https://www.gutenberg.org/ebooks/171
# https://www.gutenberg.org/ebooks/831
# https://www.gutenberg.org/ebooks/15
# https://www.gutenberg.org/ebooks/1840
# https://www.gutenberg.org/ebooks/34612
# https://www.gutenberg.org/ebooks/3013
# https://www.gutenberg.org/ebooks/60766
# https://www.gutenberg.org/ebooks/27098
# https://www.gutenberg.org/ebooks/38594
# https://www.gutenberg.org/ebooks/23464https://www.gutenberg.org/ebooks/5657
#
# https://www.gutenberg.org/ebooks/2274
# https://www.gutenberg.org/ebooks/1717
# https://www.gutenberg.org/ebooks/51002
# https://www.gutenberg.org/ebooks/40426
# https://www.gutenberg.org/ebooks/3435
# https://www.gutenberg.org/ebooks/60600
# https://www.gutenberg.org/ebooks/5500
# https://www.gutenberg.org/ebooks/74627
# https://www.gutenberg.org/ebooks/4200
# https://www.gutenberg.org/ebooks/1022
# https://www.gutenberg.org/ebooks/30576
# https://www.gutenberg.org/ebooks/14287
# https://www.gutenberg.org/ebooks/33156
# https://www.gutenberg.org/ebooks/42988
# https://www.gutenberg.org/ebooks/53094
# https://www.gutenberg.org/ebooks/700
# https://www.gutenberg.org/ebooks/12849
# https://www.gutenberg.org/ebooks/41214
# https://www.gutenberg.org/ebooks/49668
# https://www.gutenberg.org/ebooks/27238
# https://www.gutenberg.org/ebooks/208
# https://www.gutenberg.org/ebooks/33900
# https://www.gutenberg.org/ebooks/52200
# https://www.gutenberg.org/ebooks/25229
# https://www.gutenberg.org/ebooks/12219https://www.gutenberg.org/ebooks/40825
# https://www.gutenberg.org/ebooks/608
#
# https://www.gutenberg.org/ebooks/5307
# https://www.gutenberg.org/ebooks/997
# https://www.gutenberg.org/ebooks/37408
# https://www.gutenberg.org/ebooks/982
# https://www.gutenberg.org/ebooks/29024
# https://www.gutenberg.org/ebooks/63203
# https://www.gutenberg.org/ebooks/5661
# https://www.gutenberg.org/ebooks/3330
# https://www.gutenberg.org/ebooks/55024
# https://www.gutenberg.org/ebooks/53430
# https://www.gutenberg.org/ebooks/22914
# https://www.gutenberg.org/ebooks/20028
# https://www.gutenberg.org/ebooks/9334
# https://www.gutenberg.org/ebooks/12297
# https://www.gutenberg.org/ebooks/58025
# https://www.gutenberg.org/ebooks/1977
# https://www.gutenberg.org/ebooks/981
# https://www.gutenberg.org/ebooks/917
# https://www.gutenberg.org/ebooks/17090
# https://www.gutenberg.org/ebooks/13015
# https://www.gutenberg.org/ebooks/25703
# https://www.gutenberg.org/ebooks/20657
# https://www.gutenberg.org/ebooks/3261
# https://www.gutenberg.org/ebooks/52888
# https://www.gutenberg.org/ebooks/41771
# https://www.gutenberg.org/ebooks/22994
# https://www.gutenberg.org/ebooks/68185https://www.gutenberg.org/ebooks/56327
#
# https://www.gutenberg.org/ebooks/21525
# https://www.gutenberg.org/ebooks/17845
# https://www.gutenberg.org/ebooks/11417
# https://www.gutenberg.org/ebooks/16769
# https://www.gutenberg.org/ebooks/2150
# https://www.gutenberg.org/ebooks/68775
# https://www.gutenberg.org/ebooks/35688
# https://www.gutenberg.org/ebooks/14640
# https://www.gutenberg.org/ebooks/10136
# https://www.gutenberg.org/ebooks/65238
# https://www.gutenberg.org/ebooks/3733
# https://www.gutenberg.org/ebooks/1004
# https://www.gutenberg.org/ebooks/74622
# https://www.gutenberg.org/ebooks/73181
# https://www.gutenberg.org/ebooks/1289
# https://www.gutenberg.org/ebooks/45368
# https://www.gutenberg.org/ebooks/28885https://www.gutenberg.org/ebooks/18155
#
# https://www.gutenberg.org/ebooks/74619
# https://www.gutenberg.org/ebooks/16501
# https://www.gutenberg.org/ebooks/17135
# https://www.gutenberg.org/ebooks/1240
# https://www.gutenberg.org/ebooks/61085
# https://www.gutenberg.org/ebooks/60825
# https://www.gutenberg.org/ebooks/67180
# https://www.gutenberg.org/ebooks/37388
# https://www.gutenberg.org/ebooks/754
# https://www.gutenberg.org/ebooks/470
# https://www.gutenberg.org/ebooks/1732
# https://www.gutenberg.org/ebooks/6686
# 1000 libros guardados en 'books.csv'.
# Tiempo total: 60.79 segundos

# %% [markdown]
# # Clasificador

# %%
from pysentimiento import create_analyzer
import numpy as np
class EmotionAnalyzer:
    """
    Clase para analizar el estado de ánimo del usuario usando NLP avanzado.
    """

    def __init__(self):
        """Inicializa el analizador con el modelo pre-entrenado en español."""
        self.analyzer = create_analyzer(task="emotion", lang="es")

    def predict_emotion(self, text):
        """
        Predice la emoción del texto ingresado por el usuario.

        Args:
            text (str): Texto del usuario.

        Returns:
            str: Categoría de estado de ánimo.
        """
        result = self.analyzer.predict(text)
        return self._map_emotion(result.output)

    def _map_emotion(self, emotion):
        """
        Mapea las emociones del modelo a categorías personalizadas.

        Args:
            emotion (str): Emoción detectada por el modelo.

        Returns:
            str: Categoría de estado de ánimo personalizada.
        """
        emotion_map = {
            'joy': 'Alegre',
            'surprise': 'Alegre',
            'sadness': 'Melancólico',
            'anger': 'Melancólico',
            'fear': 'Melancólico',
            'disgust': 'Melancólico',
            'neutral': 'Ni fu ni fa',
            'others': 'Ni fu ni fa'
        }
        return emotion_map.get(emotion, "Desconocido")

# %%
import pandas as pd
import faiss
from sentence_transformers import SentenceTransformer
from transformers import pipeline
from mtranslate import translate
import numpy as np

class RecomendadorFAISS:
    def __init__(self, datasets):
        self.modelo = SentenceTransformer('paraphrase-MiniLM-L6-v2')
        self.resumidor = pipeline("summarization", model="facebook/bart-large-cnn")
        self.index = None
        self.data = []
        self._cargar_y_indexar_datasets(datasets)

    def _cargar_y_indexar_datasets(self, datasets):
        embeddings = []
        for ruta, columnas, columna_embed, fuente in datasets:
            df = pd.read_csv(ruta, usecols=columnas)
            df['Fuente'] = fuente
            textos = df[columna_embed].fillna("").tolist()
            emb = self.modelo.encode(textos, convert_to_tensor=False)
            embeddings.extend(emb)
            self.data.extend(df.to_dict('records'))
        embeddings = np.array(embeddings, dtype='float32')
        self._crear_indice(embeddings)

    def _crear_indice(self, embeddings):
        dimension = embeddings.shape[1]
        self.index = faiss.IndexFlatL2(dimension)
        self.index.add(embeddings)

    def recomendar(self, preferencia, emocion):
        preferencia_en = translate(preferencia, "en")
        emocion_en = translate(emocion, "en")
        preferencia_embed = self.modelo.encode([preferencia_en], convert_to_tensor=False)
        _, indices = self.index.search(np.array(preferencia_embed, dtype='float32'), 3)
        return [self._formatear_recomendacion(self.data[i], emocion_en) for i in indices[0]]

    def _formatear_recomendacion(self, item, emocion):
        fuente = item['Fuente']
        titulo = item.get('Title', item.get('game_name', 'Sin título'))
        titulo_es = translate(titulo, "es")
        descripcion = item.get('description', item.get('Summary', 'Sin descripción'))
        resumen = self._resumir_y_traducir(descripcion)
        mensaje = f"{titulo_es} - {resumen} (Fuente: {fuente})"
        if emocion == 'happy':
            return f"¡Disfruta esto! {mensaje}"
        elif emocion == 'sad':
            return f"Esto podría animarte: {mensaje}"
        else:
            return f"Interesante opción: {mensaje}"

    def _resumir_y_traducir(self, texto):
        if len(texto.split()) > 50:
            resumen = self.resumidor(texto, max_length=50, min_length=25, do_sample=False)[0]['summary_text']
            return translate(resumen, "es")
        return translate(texto, "es")

datasets = [
    ('data/bgg_database.csv', ['game_name', 'description'], 'description', 'Juego'),
    ('data/books.csv', ['Title', 'Summary'], 'Summary', 'Libro'),
    ('data/IMDB-Movie-Data.csv', ['Title', 'Description'], 'Description', 'Película')
]

recomendador = RecomendadorFAISS(datasets)

respuesta = input("Describe tu día en una frase: ")
emotion = EmotionAnalyzer()
emocion_detectada = emotion.predict_emotion(respuesta)

preferencia = input("¿Qué temática te gustaría explorar? ")
recomendaciones = recomendador.recomendar(preferencia, emocion_detectada)

print(f"Estado emocional detectado: {emocion_detectada}")
print("Recomendaciones:")
print("\n" + "-" * 40)
for rec in recomendaciones:
    print(rec)
    print("-" * 40)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.73k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/314 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-dbc7d8899e15> in <cell line: 68>()
#      66 recomendador = RecomendadorFAISS(datasets)
#      67
# ---> 68 respuesta = input("Describe tu día en una frase: ")
#      69 emotion = EmotionAnalyzer()
#      70 emocion_detectada = emotion.predict_emotion(respuesta)
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output

emotion = EmotionAnalyzer()
recomendador = RecomendadorFAISS(datasets)

frase_animo = widgets.Text(
    value='',
    placeholder='Describe tu día en una frase: ',
    description='Estado de Ánimo:',
    disabled=False
)

boton_animo = widgets.Button(
    description='Detectar Ánimo',
    button_style='primary'
)

output_animo = widgets.Output()

frase_preferencia = widgets.Text(
    value='',
    placeholder='¿Qué temática te gustaría explorar?',
    description='Preferencia:',
    disabled=True
)

boton_recomendar = widgets.Button(
    description='Recomendar',
    button_style='success',
    disabled=True
)

output_recomendaciones = widgets.Output()

emocion_detectada = None

def detectar_animo_callback(b):
    global emocion_detectada
    clear_output(wait=True)
    with output_animo:
        frase = frase_animo.value.strip()
        if frase:
            resultado = emotion.predict_emotion(frase)
            emocion_detectada = resultado
            print(f"Emoción detectada: {emocion_detectada}")

            frase_preferencia.disabled = False
            boton_recomendar.disabled = False
        else:
            print("Por favor, ingresa una frase válida.")

def recomendar_callback(b):
    clear_output(wait=True)
    with output_recomendaciones:
        preferencia = frase_preferencia.value.strip()
        if preferencia:
            recomendaciones = recomendador.recomendar(preferencia, emocion_detectada)

            print(f"Emoción: {emocion_detectada}")
            print(f"Preferencia: {preferencia}")
            print("Recomendaciones:")
            if recomendaciones:
                for rec in recomendaciones:
                    print(f"- {rec}")
            else:
                print("No se encontraron recomendaciones.")
        else:
            print("Por favor, ingresa una preferencia válida.")

boton_animo.on_click(detectar_animo_callback)
boton_recomendar.on_click(recomendar_callback)

display(
    frase_animo, boton_animo, output_animo,
    frase_preferencia, boton_recomendar, output_recomendaciones
)
# Out:
# config.json:   0%|          | 0.00/1.08k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/435M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/384 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.31M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/167 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Text(value='', description='Estado de Ánimo:', placeholder='Describe tu día en una frase: ')
# Button(button_style='primary', description='Detectar Ánimo', style=ButtonStyle())
# Output()
# Text(value='', description='Preferencia:', disabled=True, placeholder='¿Qué temática te gustaría explorar?')
# Button(button_style='success', description='Recomendar', disabled=True, style=ButtonStyle())
# Output()
